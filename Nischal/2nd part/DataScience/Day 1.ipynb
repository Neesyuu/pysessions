# %%
import numpy as np

# %%
import requests

# %%
url = 'http://databank.worldbank.org/data/reports.aspx?source=2&series=SP.POP.TOTL&country=NPL'

# %%
req = requests.get(url)

# %%
req
# Out:
# <Response [200]>

# %%
req.status_code
# Out:
# 200

# %%
req.text
# Out:
# '\r\n<!DOCTYPE html>\r\n<!--[if lt IE 7 ]> <html class="ie6"> <![endif]-->\r\n<!--[if IE 7 ]>    <html class="ie7"> <![endif]-->\r\n<!--[if IE 8 ]>    <html class="ie8"> <![endif]-->\r\n<!--[if IE 9 ]>    <html class="ie9"> <![endif]-->\r\n<!--[if (gt IE 9)|!(IE)]><!-->\r\n<html dir="ltr">\r\n<!--<![endif]-->\r\n\r\n<head>\r\n    <title>World Development Indicators| World DataBank</title>\r\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0" />\r\n    <link rel="shortcut icon" href="/data/images/favicon.ico" type="image/x-icon" />\r\n    \r\n    <!-- Bootstrap -->\r\n    <link href="/data/styles/reports/bootstrap.css" rel="stylesheet" />\r\n    <link href="/data/styles/reports/bootstrap-switch.css" rel="stylesheet" />\r\n\r\n    <link href="/data/styles/reports/jPicker-dialog.css" rel="stylesheet" />\r\n    <link href="/data/styles/reports/1.10.3/themes/smoothness/jquery-ui.css" rel="stylesheet" />\
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(req.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7 ]> <html class="ie6"> <![endif]-->
# <!--[if IE 7 ]>    <html class="ie7"> <![endif]-->
# <!--[if IE 8 ]>    <html class="ie8"> <![endif]-->
# <!--[if IE 9 ]>    <html class="ie9"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html dir="ltr">
# <!--<![endif]-->
# <head>
# <title>World Development Indicators| World DataBank</title>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/data/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <!-- Bootstrap -->
# <link href="/data/styles/reports/bootstrap.css" rel="stylesheet"/>
# <link href="/data/styles/reports/bootstrap-switch.css" rel="stylesheet"/>
# <link href="/data/styles/reports/jPicker-dialog.css" rel="stylesheet"/>
# <link href="/data/styles/reports/1.10.3/themes/smoothness/jquery-ui.css" rel="stylesheet"/>
# <link href="/data/styles/reports/jqx.base.css" rel="stylesheet"/>
# ...

# %%
soup.find('a')
# Out:
# <a class="wbg-logo" href="http://www.worldbank.org" title="The World Bank Working for a World Free of Poverty"></a>

# %%
soup.find_all('a')
# Out:
# [<a class="wbg-logo" href="http://www.worldbank.org" title="The World Bank Working for a World Free of Poverty"></a>,
#  <a class="back-btn">
#  </a>,
#  <a class="selecthomelink pull-left" href="/data/home.aspx" title="Go to home page"></a>,
#  <a class="login-btn pull-left" href="#" id="lnkSign_InOut" onclick='Javascript:onLangSelectionLogin("en")'><span class="signOut"></span><span class="login-width"> Sign In</span></a>,
#  <a class="back-btn pull-left" title="Go back to previous screen"><span class="icon-back-w img-width"></span>
#  <span class="welcome-align pull-left" style="cursor: default;"> </span>
#  </a>,
#  <a href="App_Controls/#" id="ctl10_lnkEnglish" onclick="return onLangSelection('en');" title="English">English</a>,
#  <a href="App_Controls/#" id="ctl10_lnkSpanish" onclick="return onLangSelection('es');" title="Spanish">Español</a>,
#  <a href="App_Controls/#" id="ctl10_lnkFrench" onclick="return onLangSelection('fr');" title="French">Français</a>,
# ...
